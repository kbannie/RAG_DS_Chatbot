# %% [markdown]
# # 1. 패키지 설치

# %%
#pip install langsmith openai python-dotenv langchain langchain-openai langchain-pinecone
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. 데이터 생성
#
# - Evaluation에 활용될 Question - Answer pair 생성

# %%
from langsmith import Client

client = Client()

# Define dataset: these are your test cases
dataset_name = "ds_metadata_dataset"
dataset = client.create_dataset(dataset_name)
client.create_examples(
    inputs = [
        {"input_question": "대학원 석사과정에 입학할 수 있는 자격 요건은 무엇인가요?"},
        {"input_question": "교내연구비 지원을 받을 수 없는 경우는 어떤 경우인가요?"},
        {"input_question": "조교수가 부교수로 승진하기 위한 최소 재직 기간은 얼마인가요?"},
        {"input_question": "SCIE 저널 논문의 연구실적 평가 기준은 무엇인가요?"},
        {"input_question": "기숙사 입사 제한 대상자는 누구인가요?"},
        {"input_question": "기후환경위기대응사업단의 주요 역할은 무엇인가요?"},
        {"input_question": "대학원 박사과정을 신설하려면 어떤 연구 실적 기준을 충족해야 하나요?"},
        {"input_question": "대학일자리본부는 어떤 기능을 수행하나요?"},
        {"input_question": "대학평의원회는 어떤 사항을 심의하나요?"},
        {"input_question": "덕성여자대학교의 교육 목적은 무엇인가요?"},
        {"input_question": "덕성여자대학교 도서관의 주요 업무는 무엇인가요?"},
        {"input_question": "무기계약직원의 정원은 어떻게 관리되나요?"},
        {"input_question": "부설연구소를 신설하려면 어떤 절차를 거쳐야 하나요?"},
        {"input_question": "청탁금지법 위반 시 징계 기준은 어떻게 되나요?"},
        {"input_question": "비교과교육과정위원회의 주요 기능은 무엇인가요?"},
        {"input_question": "생물안전관리위원회는 어떤 역할을 수행하나요?"},
        {"input_question": "시간외근무수당은 어떻게 지급되나요?"},
        {"input_question": "약학연구소의 주요 연구 분야는 무엇인가요?"},
        {"input_question": "연구시설·장비심의위원회는 어떤 역할을 하나요?"},
        {"input_question": "외국인 특별전형의 지원 자격은 무엇인가요?"},
        {"input_question": "외부연구과제 연구원의 임용 절차는 어떻게 되나요?"},
        {"input_question": "일반직원재심위원회의 주요 역할은 무엇인가요?"},
        {"input_question": "각 전공(학과)별 성적 우수 장학생의 기준은 무엇인가요?"},
        {"input_question": "전임교원의 학기당 책임시간은 어떻게 산정되나요?"},
        {"input_question": "진로탐색학점제는 무엇인가요?"},
        {"input_question": "차미리사교양교육연구소의 목적은 무엇인가요?"},
        {"input_question": "캠퍼스 시설을 이용하기 위해 허가를 받아야 하는 경우는 언제인가요?"},
        {"input_question": "교직원이 직무관련자를 대리하거나 고문·자문을 제공하는 경우 신고해야 하나요?"},
        {"input_question": "학생자치단체의 설립 요건은 무엇인가요?"}
        ],

    outputs=[
        {"output_answer": "각 전공(학과)별 석사과정에 지원할 수 있는 자격 요건은 국내·외 4년제 정규대학에서 학사학위를 취득한 자 또는 취득 예정인 자, 법령에 의해 동등 이상의 학력이 인정된 자입니다."},
        {"output_answer": "교내연구비를 지급받고 연구결과 제출 마감일까지 연구결과물 또는 논문게재예정증명서를 제출하지 않은 교원, 연구비 지원 신청 시 파견·휴직 중인 교원, 연구결과 평가에서 최하위 등급을 받은 후 3년이 경과되지 않은 교원은 연구비 지원을 받을 수 없습니다."},
        {"output_answer": "조교수가 부교수로 승진하기 위한 최소 재직 기간은 4년이며, 연구실적이 우수한 경우 3년으로 단축될 수 있습니다."},
        {"output_answer": "SCIE 저널 논문의 연구실적 평가는 Journal Citation Reports(JCR)에서 제공하는 Impact Factor(IF) 및 전공 저널 분야별 순위 백분율을 기준으로 합니다."},
        {"output_answer": "기숙사 입사는 학칙에 근거하여 유기정학 이상의 징계처분을 받은 학생, 감염성 질환 보균자, 재학생 중 직전 학기 성적이 2.5 미만인 학생은 제한됩니다."},
        {"output_answer": "기후환경위기대응사업단은 학술 협력 및 강의 공유를 통해 기후위기 대응을 위한 연구와 교육을 총괄하며, 전공운영위원회, 사업기획운영위원회, 자체평가위원회, 지속가능위원회를 운영합니다."},
        {"output_answer": "일반대학원에 박사과정을 신설하려는 경우, 해당 학과 교원의 2분의 1 이상이 최근 5년간 인문·사회 계열 4편 이상, 자연·공학 계열 6편 이상, 예·체능 계열 3편 이상의 연구 논문을 발표해야 합니다."},
        {"output_answer": "대학일자리본부는 본교 재학생과 지역 청년들의 효율적인 경력개발을 도모하고, 취·창업 지원 서비스의 공간적·기능적 연계를 강화하여 원스톱 고용서비스를 제공합니다."},
        {"output_answer": "대학평의원회는 대학의 발전계획, 학칙 및 대학헌장의 제·개정, 교육과정 운영, 예산 및 결산, 개방이사추천위원회 위원 추천 등의 사항을 심의합니다."},
        {"output_answer": "본 대학교의 교육 목적은 자유교육 정신을 바탕으로 창의력을 배양하고 올바른 가치관을 확립·실천하며, 세계시민의 자질을 함양하는 것입니다."},
        {"output_answer": "덕성여자대학교 도서관은 국내외 다양한 학술정보자료를 수집·개발하고 이를 보존하여 이용자의 교양 및 학습·연구를 지원하는 업무를 수행합니다."},
        {"output_answer": "무기계약직원의 정원은 본교 일반직원 정원의 10% 이내로 제한되며, 부서별로 구분하여 관리됩니다."},
        {"output_answer": "연구소를 신설하려면 관련 처장 또는 전임교원 3인 이상의 공동 발의로 산학협력단에 신청한 후 연구소심의위원회의 심의를 거쳐 총장이 설치합니다."},
        {"output_answer": "청탁금지법 위반자는 위반 금액과 직무 관련성에 따라 견책에서 파면까지 징계를 받을 수 있으며, 의례적인 금품 수수가 지속될 경우 정직 또는 해임 조치가 가능합니다."},
        {"output_answer": "비교과교육과정위원회는 비교과교육과정의 설치, 운영, 신설, 변경 및 폐지, 성과 평가 등의 사항을 심의하는 기능을 수행합니다."},
        {"output_answer": "생물안전관리위원회는 생물 관련 실험 및 유전자재조합실험의 위해성 평가, 연구시설 관리 및 점검, 생물안전 교육 및 훈련 등의 사항을 심의하는 역할을 합니다."},
        {"output_answer": "시간외근무수당은 본봉, 보직수당, 직무수당 등을 포함한 총액을 기준으로 산정되며, 1주일에 12시간을 초과하는 경우 초과 시간에 대해 별도 보상이 주어집니다."},
        {"output_answer": "약학연구소는 의약품 합성 및 신약 개발, 천연 의약자원 연구, 생리활성 및 약효 시험, 약제 기술 발전, 안전성 시험 및 생명공학을 이용한 의약품 개발을 주요 연구 분야로 합니다."},
        {"output_answer": "연구시설·장비심의위원회는 연구기관지원사업으로 구축하는 3천만원 이상 장비의 구축 결정, 1억원 이상의 장비 구축 타당성 검토, 장비의 활용 방식 결정 및 유휴 장비의 처리 등을 심의하는 역할을 합니다."},
        {"output_answer": "외국인 특별전형 지원자는 부모와 본인이 모두 외국 국적을 보유하고 있어야 하며, 한국어능력시험(TOPIK) 3급 이상 또는 이에 준하는 한국어 능력을 갖추어야 합니다."},
        {"output_answer": "연구원은 연구책임자의 제청으로 산학협력단장이 임명하며, 총장의 임명이 필요한 경우 연구책임자가 추천한 후 산학협력단장의 제청을 거쳐 총장이 임명합니다."},
        {"output_answer": " 일반직원재심위원회는 학교법인 덕성학원 산하 일반직원의 징계처분 및 기타 불리한 처분에 대한 재심을 심의하는 역할을 합니다."},
        {"output_answer": "각 전공(학과)별 성적이 직전 학기 평균 평점 3.5 이상이며, 해당 전공에서 1과목 이상을 이수한 학생 중 성적이 가장 우수한 학생이 수석으로 선발됩니다."},
        {"output_answer": "전임교원의 책임시간은 정규 학부 강의 기준으로 산정되며, 대학원 강의 중 수강인원이 3명 이상인 경우 1과목을 인정할 수 있으며, 연간 최대 2과목까지만 포함할 수 있습니다."},
        {"output_answer": "진로탐색학점제는 학생이 자신의 진로탐색을 위해 프로젝트 및 개발, 창작 등 다양한 주제와 방법으로 교과목을 스스로 설계하여 실행하고, 그 결과를 학점으로 인정하는 제도를 말합니다."},
        {"output_answer": " 연구소는 대학 교양교육의 질적 제고를 위해 교양교육 전반에 대한 연구를 수행하고 그 성과를 교육과정에 반영, 확산시키는 것을 목적으로 합니다."},
        {"output_answer": "교육·연구 시설 근처에서 소음을 발생시키는 경우, 잔디나 수목을 훼손할 우려가 있는 경우, 취사·음주·장터 개설 또는 주류 판매를 할 경우, 외부 단체가 행사를 주관하는 경우, 야간에 행사나 집회를 개최하는 경우 등은 사전에 허가를 받아야 합니다."},
        {"output_answer": "교직원 자신 또는 가족이 직무관련자를 대리하거나 직무관련자에게 고문·자문을 제공하는 경우, 법인 이사장(학교의 장)에게 신고해야 합니다."},
        {"output_answer": " 학생자치단체는 본교 학칙에 부합되는 활동이어야 하며, 단체 고유의 특성을 가져야 하고, 교내 타 단체와 중복되지 않아야 합니다."},
        ],
    metadata=[
        {"contexts": "대학원학칙시행세칙(20230710)_일부개정 파일 제3조에 따르면, 각 전공(학과)별 석사과정에 지원할 수 있는 자격 요건은 국내·외 4년제 정규대학에서 학사학위를 취득한 자 또는 취득 예정인 자, 법령에 의해 동등 이상의 학력이 인정된 자입니다."},
        {"contexts": "교내연구비관리규정(20230824)_일부개정 파일 제8조에 따르면, 교내연구비를 지급받고 연구결과 제출 마감일까지 연구결과물 또는 논문게재예정증명서를 제출하지 않은 교원, 연구비 지원 신청 시 파견·휴직 중인 교원, 연구결과 평가에서 최하위 등급을 받은 후 3년이 경과되지 않은 교원은 연구비 지원을 받을 수 없습니다."},
        {"contexts": "교원승진임용심사기준에관한내규(20230824)_일부개정 파일 제2조의2에 따르면, 조교수가 부교수로 승진하기 위한 최소 재직 기간은 4년이며, 연구실적이 우수한 경우 3년으로 단축될 수 있습니다."},
        {"contexts": "교원연구실적평가기준 운영지침(20240829)_일부개정 파일 제4조에 따르면, SCIE 저널 논문의 연구실적 평가는 Journal Citation Reports(JCR)에서 제공하는 Impact Factor(IF) 및 전공 저널 분야별 순위 백분율을 기준으로 합니다."},
        {"contexts": "기숙사규정(20220701)_일부개정 파일 제18조에 따르면, 기숙사 입사는 학칙에 근거하여 유기정학 이상의 징계처분을 받은 학생, 감염성 질환 보균자, 재학생 중 직전 학기 성적이 2.5 미만인 학생은 제한됩니다."},
        {"contexts": "기후환경위기대응사업단 운영규정(20240508)_신규제정 파일 제2조에 따르면, 기후환경위기대응사업단은 학술 협력 및 강의 공유를 통해 기후위기 대응을 위한 연구와 교육을 총괄하며, 전공운영위원회, 사업기획운영위원회, 자체평가위원회, 지속가능위원회를 운영합니다."},
        {"contexts": "대학원학칙(20241226)_일부개정 파일 제3조의2에 따르면, 일반대학원에 박사과정을 신설하려는 경우, 해당 학과 교원의 2분의 1 이상이 최근 5년간 인문·사회 계열 4편 이상, 자연·공학 계열 6편 이상, 예·체능 계열 3편 이상의 연구 논문을 발표해야 합니다."},
        {"contexts": "대학일자리본부운영규정(20220608)_일부개정 파일 제3조에 따르면, 대학일자리본부는 본교 재학생과 지역 청년들의 효율적인 경력개발을 도모하고, 취·창업 지원 서비스의 공간적·기능적 연계를 강화하여 원스톱 고용서비스를 제공합니다."},
        {"contexts": "대학평의원회규정(20240306)_일부개정 파일 제3조에 따르면, 대학평의원회는 대학의 발전계획, 학칙 및 대학헌장의 제·개정, 교육과정 운영, 예산 및 결산, 개방이사추천위원회 위원 추천 등의 사항을 심의합니다."},
        {"contexts": "덕성여자대학교학칙(20240625)_일부개정 파일 제2조에 따르면, 본 대학교의 교육 목적은 자유교육 정신을 바탕으로 창의력을 배양하고 올바른 가치관을 확립·실천하며, 세계시민의 자질을 함양하는 것입니다."},
        {"contexts": "도서관규정(20221207)_일부개정 파일 제2조에 따르면, 덕성여자대학교 도서관은 국내외 다양한 학술정보자료를 수집·개발하고 이를 보존하여 이용자의 교양 및 학습·연구를 지원하는 업무를 수행합니다."},
        {"contexts": "무기계약직원규정(20241226)_일부개정 파일 제4조에 따르면, 무기계약직원의 정원은 본교 일반직원 정원의 10% 이내로 제한되며, 부서별로 구분하여 관리됩니다."},
        {"contexts": "부설연구소의설치및운영에관한규정_20081226 파일 제3조에 따르면, 연구소를 신설하려면 관련 처장 또는 전임교원 3인 이상의 공동 발의로 산학협력단에 신청한 후 연구소심의위원회의 심의를 거쳐 총장이 설치합니다."},
        {"contexts": "부정청탁및금품등수수의금지에관한법률시행령제43조에따른징계기준등 파일 제4조에 따르면, 청탁금지법 위반자는 위반 금액과 직무 관련성에 따라 견책에서 파면까지 징계를 받을 수 있으며, 의례적인 금품 수수가 지속될 경우 정직 또는 해임 조치가 가능합니다."},
        {"contexts": "비교과교육과정위원회규정(20240605)_일부개정 파일 제2조에 따르면, 비교과교육과정위원회는 비교과교육과정의 설치, 운영, 신설, 변경 및 폐지, 성과 평가 등의 사항을 심의하는 기능을 수행합니다."},
        {"contexts": "생물안전관리규정_20170412 파일 제6조에 따르면, 생물안전관리위원회는 생물 관련 실험 및 유전자재조합실험의 위해성 평가, 연구시설 관리 및 점검, 생물안전 교육 및 훈련 등의 사항을 심의하는 역할을 합니다."},
        {"contexts": "시간외근무수당지급내규_20070301 파일 제5조에 따르면, 시간외근무수당은 본봉, 보직수당, 직무수당 등을 포함한 총액을 기준으로 산정되며, 1주일에 12시간을 초과하는 경우 초과 시간에 대해 별도 보상이 주어집니다."},
        {"contexts": "약학연구소규정_20081226 파일 제4조에 따르면, 약학연구소는 의약품 합성 및 신약 개발, 천연 의약자원 연구, 생리활성 및 약효 시험, 약제 기술 발전, 안전성 시험 및 생명공학을 이용한 의약품 개발을 주요 연구 분야로 합니다."},
        {"contexts": "연구시설·장비심의위원회규정(20210308)_일부개정 파일 제4조에 따르면, 연구시설·장비심의위원회는 연구기관지원사업으로 구축하는 3천만원 이상 장비의 구축 결정, 1억원 이상의 장비 구축 타당성 검토, 장비의 활용 방식 결정 및 유휴 장비의 처리 등을 심의하는 역할을 합니다."},
        {"contexts": "외국인학생규정(20230607)_일부개정 파일 제3조에 따르면, 외국인 특별전형 지원자는 부모와 본인이 모두 외국 국적을 보유하고 있어야 하며, 한국어능력시험(TOPIK) 3급 이상 또는 이에 준하는 한국어 능력을 갖추어야 합니다."},
        {"contexts": "외부연구과제 연구원 내규(20190729)_일부개정 파일 제4조에 따르면, 연구원은 연구책임자의 제청으로 산학협력단장이 임명하며, 총장의 임명이 필요한 경우 연구책임자가 추천한 후 산학협력단장의 제청을 거쳐 총장이 임명합니다."},
        {"contexts": "일반직원재심위원회규정_19930101 파일 제1조에 따르면, 일반직원재심위원회는 학교법인 덕성학원 산하 일반직원의 징계처분 및 기타 불리한 처분에 대한 재심을 심의하는 역할을 합니다."},
        {"contexts": "장학금규정시행세칙(20241113)_일부개정 파일에 따르면, 각 전공(학과)별 성적이 직전 학기 평균 평점 3.5 이상이며, 해당 전공에서 1과목 이상을 이수한 학생 중 성적이 가장 우수한 학생이 수석으로 선발됩니다."},
        {"contexts": "전임교원책임시간및초과강의료지급내규(20240904)_일부개정 파일 제3조에 따르면, 전임교원의 책임시간은 정규 학부 강의 기준으로 산정되며, 대학원 강의 중 수강인원이 3명 이상인 경우 1과목을 인정할 수 있으며, 연간 최대 2과목까지만 포함할 수 있습니다."},
        {"contexts": "진로탐색학점제 운영규정(20240214)_일부개정 파일 제2조에 따르면, 진로탐색학점제는 학생이 자신의 진로탐색을 위해 프로젝트 및 개발, 창작 등 다양한 주제와 방법으로 교과목을 스스로 설계하여 실행하고, 그 결과를 학점으로 인정하는 제도를 말합니다."},
        {"contexts": "차미리사교양교육연구소규정(20240904)_일부개정 파일 제2조에 따르면, 연구소는 대학 교양교육의 질적 제고를 위해 교양교육 전반에 대한 연구를 수행하고 그 성과를 교육과정에 반영, 확산시키는 것을 목적으로 합니다."},
        {"contexts": "캠퍼스시설이용규정(20241204)_일부개정 파일 제6조에 따르면, 교육·연구 시설 근처에서 소음을 발생시키는 경우, 잔디나 수목을 훼손할 우려가 있는 경우, 취사·음주·장터 개설 또는 주류 판매를 할 경우, 외부 단체가 행사를 주관하는 경우, 야간에 행사나 집회를 개최하는 경우 등은 사전에 허가를 받아야 합니다."},
        {"contexts": "학교법인 덕성학원 및 설치학교 임원·교직원 행동강령(20241021)_일부개정 파일 제5조에 따르면, 교직원 자신 또는 가족이 직무관련자를 대리하거나 직무관련자에게 고문·자문을 제공하는 경우, 법인 이사장(학교의 장)에게 신고해야 합니다."},
        {"contexts": "학생자치단체설립·운영및활동규정(20220701)_일부개정 파일 제4조에 따르면, 학생자치단체는 본교 학칙에 부합되는 활동이어야 하며, 단체 고유의 특성을 가져야 하고, 교내 타 단체와 중복되지 않아야 합니다."},
                ],
    dataset_id=dataset.id,
)

# %% [markdown]
# # 3. Retriever 생성
#
# - Evaluation을 위한 Retriever 생성
# - 3.x 에서 생성한 Pinecone Retriever

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dotenv import load_dotenv
from langchain_openai import OpenAIEmbeddings, UpstageEmbeddings

load_dotenv()

embedding = OpenAIEmbeddings(model='text-embedding-3-large')

# %%
from langchain_pinecone import PineconeVectorStore

index_name = 'ds-markdown-clean'

database = PineconeVectorStore.from_existing_index(index_name=index_name, embedding=embedding)
retriever = database.as_retriever()

# %% [markdown]
# # 4. LLM 답변 생성을 위한 RagBot
#
# - retriever와 OpenAI API를 활용한 RAG

# %%
### RAG bot

import openai
from langsmith import traceable
from langsmith.wrappers import wrap_openai
from llm import get_retriever

# llm.py의 get_retriever()를 사용하여 retriever 가져오기
retriever = get_retriever()

class RagBot:

    def __init__(self, retriever, model: str = "gpt-4o"):
        # 위에서 선언한 retriever를 할용해서 Retrieval 실행
        self._retriever = retriever
        # Wrapping the client instruments the LLM
        # LangSmith 문법
        self._client = wrap_openai(openai.Client())
        self._model = model

    @traceable()
    def retrieve_docs(self, question):
        return self._retriever.invoke(question)

    @traceable()
    def invoke_llm(self, question, docs):
        # `retrieve_docs()` 를 통해 가져온 문서들을 system prompt로 전달
        response = self._client.chat.completions.create(
            model=self._model,
            messages=[
                {
                    "role": "system",
                    "content": "당신은 덕성여자대학교 규정 전문가입니다."
                    "아래에 제공된 문서 내용을 참고하여 답변을 작성해야 합니다.\n\n"
                    f"## 덕성여대 규정\\n\\n{docs}",
                },
                {"role": "user", "content": question},
            ],
        )

        # Evaluators 를 활용해서 `answer`와 `context`를 평가할 예정
        return {
            "answer": response.choices[0].message.content,
            "contexts": [str(doc) for doc in docs],
        }

    @traceable()
    def get_answer(self, question: str):
        docs = self.retrieve_docs(question)
        return self.invoke_llm(question, docs)

rag_bot = RagBot(retriever)

# %%
def predict_rag_answer(example: dict):
    """답변만 평가할 때 사용"""
    response = rag_bot.get_answer(example["input_question"])
    return {"answer": response["answer"]}

def predict_rag_answer_with_context(example: dict):
    """Context를 활용해서 hallucination을 평가할 때 사용"""
    response = rag_bot.get_answer(example["input_question"])
    return {"answer": response["answer"], "contexts": response["contexts"]}

# %%
from langchain import hub
from langchain_openai import ChatOpenAI

# Grade prompt
# 답변의 정확도를 측정하기위해 사용되는 프롬프트
grade_prompt_answer_accuracy = prompt = hub.pull("langchain-ai/rag-answer-vs-reference")

def answer_evaluator(run, example) -> dict:
    """
    RAG 답변 성능을 측정하기 위한 evaluator
    """

    # `example`이 데이터를 생성할 때 입력한 `Question-Answer` pair. `run`은 `RagBot`을 활용해서 생성한 LLM의 답변
    input_question = example.inputs["input_question"]
    reference = example.outputs["output_answer"]
    prediction = run.outputs["answer"]

    # LLM Judge로 사용될 LLM
    llm = ChatOpenAI(model="gpt-4o", temperature=0)

    # LLM 응답을 위한 LCEL 활용
    # 3.6 `dictionary_chain`의 `prompt | llm | StrOutputParser()`` 의 구조와 유사함
    answer_grader = grade_prompt_answer_accuracy | llm

    # Evaluator 실행
    score = answer_grader.invoke({"question": input_question,
                                  "correct_answer": reference,
                                  "student_answer": prediction})
    score = score["Score"]

    return {"key": "answer_v_reference_score", "score": score}

# %%
# Grade prompt
# 답변이 사용자의 질문에 얼마나 도움되는지 판단하는 프롬프트
grade_prompt_answer_helpfulness = prompt = hub.pull("langchain-ai/rag-answer-helpfulness")

def answer_helpfulness_evaluator(run, example) -> dict:
    """
    답변이 사용자의 질문에 얼마나 도움되는지 판단하는 Evaluator
    """

    # 데이터셋의 답변과 비교하지 않고, 데이터셋의 질문에 대한 LLM의 답변의 가치를 평가함
    input_question = example.inputs["input_question"]
    prediction = run.outputs["answer"]

    # LLM Judge로 사용될 LLM
    llm = ChatOpenAI(model="gpt-4o", temperature=0)

    # LLM 응답을 위한 LCEL 활용
    # 3.6 `dictionary_chain`의 `prompt | llm | StrOutputParser()`` 의 구조와 유사함
    answer_grader = grade_prompt_answer_helpfulness | llm

    # Evaluator 실행
    score = answer_grader.invoke({"question": input_question,
                                  "student_answer": prediction})
    score = score["Score"]

    return {"key": "answer_helpfulness_score", "score": score}

# %%
# Prompt
# hallucination 판단을 위한 프롬프트
grade_prompt_hallucinations = prompt = hub.pull("langchain-ai/rag-answer-hallucination")

def answer_hallucination_evaluator(run, example) -> dict:
    """
    hallucination 판단을 위한 Evaluator
    """

    # 데이터셋에 있는 질문과, LLM이 답변을 생성할 때 사용한 context를 활용
    input_question = example.inputs["input_question"]
    contexts = run.outputs["contexts"]

    # LLM의 답변
    prediction = run.outputs["answer"]

    # LLM Judge로 사용될 LLM
    llm = ChatOpenAI(model="gpt-4o", temperature=0)

    # LLM 응답을 위한 LCEL 활용
    # 3.6 `dictionary_chain`의 `prompt | llm | StrOutputParser()`` 의 구조와 유사함
    answer_grader = grade_prompt_hallucinations | llm

    # Evaluator 실행
    score = answer_grader.invoke({"documents": contexts,
                                  "student_answer": prediction})
    score = score["Score"]

    return {"key": "answer_hallucination", "score": score}

# %%
from langsmith.evaluation import evaluate

dataset_name = "ds_nosource_dataset"
experiment_results = evaluate(
    predict_rag_answer_with_context, # 어떤 함수를 활용해서 LLM 답변을 확인할지 지정, hallucination 판단 여부에 따라 `with_context` 사용
    data=dataset_name, # Evaluation에 사용될 dataset의 이름
    evaluators=[answer_evaluator, answer_helpfulness_evaluator, answer_hallucination_evaluator], # 실행할 Evaluator의 종류
    experiment_prefix="ds-evaluator-lecture-hallucination-outputRevise",
    metadata={"version": "income tax v1, gpt-4o"}, 
)
# Out:
# View the evaluation results for experiment: 'ds-evaluator-lecture-hallucination-outputRevise-a20c9c09' at:
# https://smith.langchain.com/o/ff9664c6-9f8d-42be-9e90-1a0879aa2325/datasets/a37fd4a2-9b9c-4068-9b99-1dcc6976aa9a/compare?selectedSessions=49ce8801-de52-49f2-9d4d-38a1d881c384
# 0it [00:00, ?it/s]
